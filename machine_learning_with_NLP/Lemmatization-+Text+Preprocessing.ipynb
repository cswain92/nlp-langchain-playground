# %% [markdown]
# ## 📖 WordNet Lemmatizer (Simple Explanation)
#
# **Lemmatization** is similar to stemming, but it returns a **real dictionary word** (called a *lemma*).
#
# 👉 Unlike stemming:
# - Stemming → may give incorrect words (`studies → studi ❌`)
# - Lemmatization → gives correct words (`studies → study ✅`)
#
# ---
#
# ### 🧠 Key Idea
#
# The **WordNet Lemmatizer** uses the WordNet dictionary to find the correct base form of a word.
#
# ---
#
# ### 💻 Example (Using NLTK)
#
# ```python
# from nltk.stem import WordNetLemmatizer
#
# lemmatizer = WordNetLemmatizer()
#
# print(lemmatizer.lemmatize("running", pos="v"))  # run
# print(lemmatizer.lemmatize("better", pos="a"))   # good

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/chiranjib/nltk_data...
# True

# %%
## Q&A, chatboats, text summerization
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### ⚡ Important Point
#
# 👉 You should pass POS (Part of Speech) for accurate results:
#
# - "v" → verb
# - "n" → noun
# - "a" → adjective
# - "r" → adverb

# %%
print(lemmatizer.lemmatize("running",pos='v'))
# Out:
# run

# %%
words = [
    "studies",     # studi ❌ → study ✅
    "flies",       # fli ❌ → fly ✅
    "cries",       # cri ❌ → cry ✅
    "better",      # better ❌ → good ✅
    "best",        # best ❌ → good ✅
    "worse",       # wors ❌ → bad ✅
    "went",        # went ❌ → go ✅
    "gone",        # gone ❌ → go ✅
    "children",    # children ❌ → child ✅
    "mice",        # mice ❌ → mouse ✅
    "geese",       # gees ❌ → goose ✅
    "feet",        # feet ❌ → foot ✅
    "teeth",       # teeth ❌ → tooth ✅
    "men",         # men ❌ → man ✅
    "women" ,       # women ❌ → woman ✅
    "history"
]

# %%
for word in words:
    print(word+"---->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# studies---->study
# flies---->fly
# cries---->cry
# better---->better
# best---->best
# worse---->worse
# went---->go
# gone---->go
# children---->children
# mice---->mice
# geese---->geese
# feet---->feet
# teeth---->teeth
# men---->men
# womenhistory---->womenhistory
